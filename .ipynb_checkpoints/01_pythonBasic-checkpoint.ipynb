# %%
a = 5

# %%
b = 32

# %%
a +b
# Out:
# 37

# %%
name = "shibam"

# %%
print("Hello World") #yooo chiillll
# Out:
# Hello World

# %%
# Hello This is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(name)
# Out:
# str

# %%
a = "6547"

# %%
b = "717717"

# %%
print(a+b)
# Out:
# 6547717717

# %%
int(a) + int(b) #typecasting
# Out:
# 724264
