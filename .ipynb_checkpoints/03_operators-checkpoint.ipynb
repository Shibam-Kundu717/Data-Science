# %%
a = 4
b = 90

# %%
a+b
# Out:
# 94

# %%
a-b
# Out:
# -86

# %%
a/b
# Out:
# 0.044444444444444446

# %%
b**a
# Out:
# 65610000

# %%
a > b
# Out:
# False

# %%
a = b

# %%
print(b)
# Out:
# 90

# %%
print(a)
# Out:
# 90

# %%
a == b
# Out:
# True

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
11/2
# Out:
# 5.5

# %%
11//2
# Out:
# 5
