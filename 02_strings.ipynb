# %%
name = "shibam"

# %%
name
# Out:
# 'shibam'

# %%
name.upper()
# Out:
# 'SHIBAM'

# %%
name.endswith("bam")
# Out:
# True

# %%
name.lower()
# Out:
# 'shibam'

# %%
name.count("a")
# Out:
# 1

# %%
s = "AT that moment "
print(len(s))
# Out:
# 15

# %%
s[0:5] #string slicing
# Out:
# 'AT th'

# %%
s[1:-1]
# Out:
# 'T that moment'
