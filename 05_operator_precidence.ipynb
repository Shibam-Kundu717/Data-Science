# %%
result = 10 + 2 * 3

# %%
result
# Out:
# 16

# %%
 2**3**2
# Out:
# 512

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %%
2**5+34/36**5-56*23+999
# Out:
# -256.9999994377022

# %%
6*8
# Out:
# 48
