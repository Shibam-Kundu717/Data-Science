# %%
def http_status(code):
    match code :
        case 200:  
            return "ok"
        case 404:
            return "Bad Request"
        case 500:
            return "Internal Servere Error"
        case _:
            return "unknown Status"
print(http_status(200)) #output is ok
print(http_status(404)) #output not found
# Out:
# ok
# Bad Request
