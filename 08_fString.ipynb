# %%
s = "Shibam"

# %%
s[1]
# Out:
# 'h'

# %%
s.upper()
# Out:
# 'SHIBAM'

# %%
name = "swadesh"
age = 22
print(f"Hello my name is {name} and my age is {age}")
# Out:
# Hello my name is swadesh and my age is 22

# %%
pi = 3.14159
print(f"pi rounded to 2 decimal places:{pi:.2f}")
# Out:
# pi rounded to 2 decimal places:3.14

# %%
print(f"{'python' :<10}")
print(f"{'python' :>10}")
print(f"{'python' :^10}")
# Out:
# python
#     python
#   python
