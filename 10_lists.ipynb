# %%
l = [3,2,445,6,788,54]

# %%
l[0] # same as array
# Out:
# 3

# %%
l[0] = 34

# %%
l.append(56)

# %%
l
# Out:
# [34, 2, 445, 6, 788, 54, 56]

# %%
l2 = [3,717]

# %%
l.extend(l2)

# %%
l
# Out:
# [34, 2, 445, 6, 788, 54, 56, 3, 717]

# %%
l.insert(1,717)

# %%
l
# Out:
# [34, 717, 2, 445, 6, 788, 54, 56, 3, 717]

# %%
l.pop(4)
# Out:
# 6

# %%
l
# Out:
# [34, 717, 2, 445, 788, 54, 56, 3, 717]

# %%
l.index(717)
# Out:
# 1

# %%
l.append(4)

# %%
l
# Out:
# [34, 717, 2, 445, 788, 54, 56, 3, 717, 4]

# %%
l.count(4)
# Out:
# 1

# %%
l.count(717)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [2, 3, 4, 34, 54, 56, 445, 717, 717, 788]

# %%
sorted(l)
# Out:
# [2, 3, 4, 34, 54, 56, 445, 717, 717, 788]

# %%
newl = [47,55,326,666,2323244,55]

# %%
sorted(newl)
# Out:
# [47, 55, 55, 326, 666, 2323244]

# %%
newl
# Out:
# [47, 55, 326, 666, 2323244, 55]

# %%
####NESTED LIST####

# %%
y = [1,23,True,False,[4,7]]

# %%
y
# Out:
# [1, 23, True, False, [4, 7]]

# %%
y[4][1]
# Out:
# 7

# %%
list1 = [1,2,3.4,334,334]

# %%
list2 = [2,2,3,45,6]

# %%
list1+list2 #list concatination
# Out:
# [1, 2, 3.4, 334, 334, 2, 2, 3, 45, 6]

# %%
if 3 in list2:
    print("YOO chiLL")
# Out:
# YOO chiLL

# %%
s = "Arijit-sibabrata-subhajit-diya"

# %%
s.split("-")
# Out:
# ['Arijit', 'sibabrata', 'subhajit', 'diya']
