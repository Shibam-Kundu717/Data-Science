# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
student = {
    "name" : "Shibam",
    "age" : 25,
    "grade" :"A"
}

# %%
student["name"]
# Out:
# 'Shibam'

# %%
student.get("name")
# Out:
# 'Shibam'

# %%
student["age"] = 66

# %%
student
# Out:
# {'name': 'Shibam', 'age': 66, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Shibam', 66, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Shibam'), ('age', 66), ('grade', 'A')])

# %%
student.update({"name": "DIya","language":"dhus bola"})

# %%
student
# Out:
# {'name': 'DIya', 'age': 66, 'grade': 'A', 'language': 'dhus bola'}
