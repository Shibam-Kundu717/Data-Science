# %%
f = open("text.txt","r")

# %%
f.read()
# Out:
# 'Shibam\nis a\ngood\nboy\n'

# %%
s = "yooo chilll"

# %%
f.close()

# %%
f = open("Shibam.txt","w")
s = "yooooooooo chilllllllll"

# %%
f.write(s)
# Out:
# 23

# %%
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
with open("Shibam.txt","r") as file:
    content = file.read()
    print(content)

# %%
import json

# %%
obj = {"name":"SHibam","company":"microsoft","salary":45000}
s = json.dumps(obj)
type(s)
# Out:
# str

# %%
d = json.loads('{"name":"SHibam","company":"microsoft","salary":45000}')

# %%
type(d)
# Out:
# dict

# %%
file = open("data.json","w")

# %%
json.dump(obj,file)

# %%
file.close()
